# %% [markdown]
# # Tutorial 2 - MicaSense library
#
# This tutorial assumes you have gone through the [basic setup](./Micasense Image Processing Setup.ipynb) and builds on the basic radiance, irradiance, and reflectance concepts and code covered in the [first tutorial](./MicaSense Image Processing Tutorial 1.ipynb).
#
# In this tutorial, we will cover usage of the MicaSense python library to access images and groups of images.  Most of the processing details are hidden away in the library, but the library code is open and available in the git repository.
#
# # Library Components
#
# In the first tutorial, we introduced `micasense.utils` which provided some helper functions for single image manipulation, and `micasense.plotutils` which provided some plotting helpers.
#
# For this second tutorial, we are going to introduce the usage of the included micasense libraries for opening, converting, and displaying images. This will allow us to discuss and visualize results at a high level, while the underlying source code is available for those interested in the implementation details.  In some cases, the libraries themselves may be enough to implement a custom workflow without the need to re-implement or translate the code to another system or language.
#
# The library code provides some basic classes to manage image data.  At the highest level is the `ImageSet`, which is able to load a list of files or recursively search a whole directory into data structures which are easy to access and manipulate.  `ImageSet`s are made up of `Capture`s, which hold the set of (usually 5) images as they are simultaneously gathered by the RedEdge camera.  Within `Capture`s are `Image`s, which hold a single image file and allow easy access to the image metadata.  The `Image` class also provides the ability to extract metadata from individual images and to convert individual images in similar ways to those described in the first tutorial.
#
# For the rest of this article, we will look at each of the objects available starting with the single `Image` object, and work our way up to the whole `ImageSet`.  Each section in this article is standalone, and can be copied into another workbook or edited in place to explore more of the functions associated with that object.

# %% [markdown]
# ## micasense.Image
#
# An image is the lowest level object. It represents the data in a single tiff file as taken by the camera.  `Image` objects expose a set of data retrieval methods which provide access to raw, radiance, and reflectance corrected images, and to undistort any of those images. Note that when retrieving image data from an `Image` object, the data is stored internally in the object, increasing the object's memory footprint. If operating on a large number of images, it may be necessary to release this data memory after each image is processed to limit the program memory footprint. This can be done by calling the `Image.clear_image_data()` method.

# %%
import os
import micasense.image as image
# %matplotlib inline

# image_path = os.path.join('.','data','ALTUM','IMG_0000_1.tif')

imagePath = os.path.join('.','data','0006SET','000')
imagePath = os.path.join('.','data','07112023_DeerCreek\\40_111\\000')

imageName = os.path.join(imagePath,'IMG_0000_1.tif')

img = image.Image(imageName)
img.plot_raw();
# Out:
# .\data\ALTUM\IMG_0000_1.tif

# %% [markdown]
# ### Accessing `Image` Metadata
#
# Metadata for each image is available in the `Image.meta` parameter.  This object is a `micasense.Metadata` object and can be accessed directly for image specific metadata extraction. Below, we print the same metadata values as we did in Tutorial #1, but using direct access to the `Metadata` object parameters.
#
# A notebook for experimenting with the `Image` class can be found [here](Images.ipynb).

# %%
print('{0} {1} firmware version: {2}'.format(img.meta.camera_make(),
                                             img.meta.camera_model(), 
                                             img.meta.firmware_version()))
print('Exposure Time: {0} seconds'.format(img.meta.exposure()))
print('Imager Gain: {0}'.format(img.meta.gain()))
print('Size: {0}x{1} pixels'.format(img.meta.image_size()[0],
                                    img.meta.image_size()[1]))
print('Band Name: {0}'.format(img.meta.band_name()))
print('Center Wavelength: {0} nm'.format(img.meta.center_wavelength()))
print('Bandwidth: {0} nm'.format(img.meta.bandwidth()))
print('Capture ID: {0}'.format(img.meta.capture_id()))
print('Flight ID: {0}'.format(img.meta.flight_id()))
# Out:
# MicaSense RedEdge-P firmware version: v1.3.1
# Exposure Time: 0.00133818 seconds
# Imager Gain: 1.0
# Size: 1456x1088 pixels
# Band Name: Blue
# Center Wavelength: 475 nm
# Bandwidth: 32 nm
# Capture ID: F5a66c3wn6PDTmrFdhZp
# Flight ID: K6K66kMHDva0VTpBkmXt

# %% [markdown]
# ## micasense.Capture
#
# The `Capture` class is a container for `Image`s which allows access to metadata common to the group of images. The internal `Image` objects are accessible via the `capture.images` properties, and images in this list are kept sorted by the `band` property.  Data which is different for each image can be accessed through composite methods, such as the `capture.dls_irradiance()` method, which returns a list of irradiances in band order.

# %%
import os, glob
import micasense.capture as capture

# images_path = os.path.join('.','data','ALTUM')
# images_path = os.path.join('.','data','0006SET','000')
images_path = os.path.join('.','data','07112023_DeerCreek\\40_111\\000')


image_names = glob.glob(os.path.join(images_path,'IMG_0000_*.tif'))
cap = capture.Capture.from_filelist(image_names)
cap.plot_radiance();

# %% [markdown]
# ### Acessing `Capture` metadata
#
# Metadata which is common to all captures can be accessed via methods on the `Capture` object.  Metadata which varies between the images of the capture, such as DLS information, is available as lists accessed from the capture object.
#
# <div class="alert alert-info">
#   <strong>Note:</strong> The lists returned from metadata access on the `Capture` object are returned in `band_index` order.  All images within a capture are sorted by the image `band_index`, and all lists adhere to this ordering.  This ordering is consistent with the number at the end of each filename of a RedEdge image.
# </div>
#
# Below we plot the raw and tilt compensated DLS irradiance by center wavelength and by band name.

# %%
import matplotlib.pyplot as plt

print(cap.band_names())
fig = plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.scatter(cap.center_wavelengths(), cap.dls_irradiance())
plt.ylabel('Irradiance $(W/m^2/nm)$')
plt.xlabel('Center Wavelength (nm)')
plt.subplot(1,2,2)
plt.scatter(cap.band_names(), [img.meta.exposure() for img in cap.images])
plt.xlabel('Band Names')
plt.ylim([0,2.5e-3])
plt.ylabel('Exposure Time (s)')
plt.show()
# Out:
# ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']

# %% [markdown]
# A notebook for experimenting with the `Capture` class can be found [here](Captures.ipynb).

# %% [markdown]
# ## micasense.Panel
#
# The `Panel` class is a helper class which can automatically extract panel information from MicaSense calibrated reflectance panels by finding the QR code within an image and using the QR Code location and orientation information to find the lambertian panel area.  The class then allows extraction of statistics from the panel area such as mean raw values, mean radiance, standard deviation, and the number of saturated pixels in the panel region. The panel object can be included standalone, or used within the context of a `Capture` object.
#
# <div class="alert alert-info">
#   <strong>Note:</strong> For the automatic panel QR code finding functions of the library to work, zbar and it's python bindings must be installed. We have made every effort to ensure this fails gracefully if zbar isn't available. Unfortunately zbar is only available using Python 2.7, not Python 3.  If you're using Python 3.x, the code available in '/micasense/panel.py' shows how to find QR codes in images and to find the panel area from the QR location.  We're currently looking for Python QR code finding options that work across platforms and Python versions, let us know if you have one that supports location!
# </div>

# %%
import os
import micasense.image as image
import micasense.panel as panel

# image_path = os.path.join('.','data','ALTUM','IMG_0000_1.tif')
image_path = os.path.join('.','data','07112023_DeerCreek\\40_111\\000','IMG_0000_1.tif')
img = image.Image(image_path)

pnl = panel.Panel(img)
print("Panel found: {}".format(pnl.panel_detected()))
print("Panel serial: {}".format(pnl.serial))
print("QR Code Corners:\n{}".format(pnl.qr_corners()))
mean, std, count, saturated_count = pnl.raw()
print("Panel mean raw pixel value: {}".format(mean))
print("Panel raw pixel standard deviation: {}".format(std))
print("Panel region pixel count: {}".format(count))
print("Panel region saturated pixel count: {}".format(count))

pnl.plot();
# Out:
# Panel found: False
# Panel serial: None
# QR Code Corners:
# None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 13
#      11 print("Panel serial: {}".format(pnl.serial))
#      12 print("QR Code Corners:\n{}".format(pnl.qr_corners()))
# ---> 13 mean, std, count, saturated_count = pnl.raw()
#      14 print("Panel mean raw pixel value: {}".format(mean))
#      15 print("Panel raw pixel standard deviation: {}".format(std))
#
# File G:\GIT_Repo\micasense\imageprocessing\micasense\panel.py:256, in Panel.raw(self)
#     254 def raw(self):
#     255     raw_img = self.image.undistorted(self.image.raw())
# --> 256     return self.region_stats(raw_img,
#     257                              self.panel_corners(),
#     258                              sat_threshold=65000)
#
# File G:\GIT_Repo\micasense\imageprocessing\micasense\panel.py:239, in Panel.region_stats(self, img, region, sat_threshold)
#     235 def region_stats(self, img, region, sat_threshold=None):
#     236     """Provide regional statistics for an image over a region
#     237     Inputs: img is any image ndarray, region is a skimage shape
#     238     Outputs: mean, std, count, and saturated count tuple for the region"""
# --> 239     rev_panel_pts = np.fliplr(region)  # skimage and opencv coords are reversed
#     240     w, h = img.shape
#     241     mask = measure.grid_points_in_poly((w, h), rev_panel_pts)
#
# File <__array_function__ internals>:200, in fliplr(*args, **kwargs)
#
# File ~\anaconda3\envs\micasense\lib\site-packages\numpy\lib\twodim_base.py:98, in fliplr(m)
#      96 m = asanyarray(m)
#      97 if m.ndim < 2:
# ---> 98     raise ValueError("Input must be >= 2-d.")
#      99 return m[:, ::-1]
#
# ValueError: Input must be >= 2-d.

# %% [markdown]
# A notebook for experimenting with the `Panel` class can be found [here](Panels.ipynb)

# %% [markdown]
# ## micasense.ImageSet
#
# An `ImageSet` contains a group of `Capture`s. The captures can be loaded from image object, from a list of files, or by recursively searching a directory for images.
#
# Loading an `ImageSet` can be a time consuming process.  It uses python multithreading under the hood to maximize cpu usage on multi-core machines.

# %%
from ipywidgets import FloatProgress
from IPython.display import display
f = FloatProgress(min=0, max=1)
display(f)
def update_f(val):
    f.value=val

import micasense.imageset as imageset
import os
# images_dir = os.path.join('.','data','ALTUM')
images_dir = os.path.join('.','data','07112023_DeerCreek\\40_111\\000')


imgset = imageset.ImageSet.from_directory(images_dir, progress_callback=update_f)

for cap in imgset.captures:
    print ("Opened Capture {} with bands {}".format(cap.uuid,[str(band) for band in cap.band_names()]))
# Out:
# FloatProgress(value=0.0, max=1.0)
# Opened Capture F5a66c3wn6PDTmrFdhZp with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture ae2CRGms1XinChSWSqcD with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture jy9Z5moyXlJJzZF8zIxP with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 5JAUjf0IbYTZAu4WkvQE with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 22CHFji8rInJc5wxcQvu with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 6w9POGoOxtWFr6MYfjLn with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture I4701pDhNCOViOONHvDI with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture wk7CSsGfKoJC7BMkvaD4 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 1viKm0UzDjE4JyTAvycN with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture WUG3hn2jm5P1yecdaV4b with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture ZDP6IcoFCMdbimndLWPu with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 2zNFc20n0KdAOeNvpTUn with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture MIiqFR3T1FIohCZlCYMq with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture PXSZjSGx77395LBpEH1H with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture lC81Sr5zOd0LzVJ2kGaK with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture EKuCnHMIQm5pfkTeNA5f with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture odGI6T6cI0JNtaD8lt0e with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture c7neEYlhJiaMfCI9wTmi with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture n8wBq3vixYoEslIRqEcJ with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture aXSuGPAUT7UPxBE75obr with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 5FSHaiCmULWXP0Lsa7OJ with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 2EB7bgsBags0loYfFPm1 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 11jJzt998CxzUzw9mry1 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 8jjmxZz2gM7D04wzuKcI with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture WgV4RE3RY1wBe3xWoFpy with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture qGlBcb3DL691O0lkFkhP with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture O130SbEHa5n4SMUs8xMh with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture VWx0n5WiOGxN4tIPfjIF with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture p2BizC1nJlLdvqMfz8LB with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 0GYCipS7oRRx0gKrQFRd with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 6GEWk7LAlOdpk3Y3n4ZK with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture YTMs7LCwM57dKKsRVAAM with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 2DqylC0tnMdA65pHqs20 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture Iv2CL8KkmAKjyvJ3gjC7 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture g3j6HdUeut56uZvFsjZc with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 3rRm5zyXNM8McC0j6QUj with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture sKf1s4D27ZfqeroN8Xn0 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture XugPA2UFd6pfdjnzy0MW with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 6VUtopR9DiCfWv220J9W with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture uk1LfMwVmQDW042tBeER with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 11ZdA5zQqK55UBWnCK8M with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture HNebfL0fpvbQemybIVvD with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture JMp5lIM8xn9aAru9oWqE with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture hkSTCHyYt14WtILTsN8m with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture Sawh23ZLMdj6HM3DRkjt with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture o4azrUBcvcHCjqO4asM5 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture xW41izB8AamUjK3dCvNf with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture G1SXfj4S4Aar3Ctg8bN0 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture W7D3zjMIaGnvfD1fYNe7 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture wQN05pVyRUCo1mNoerVg with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture gcwh3mJf05P2P3Y8EZG7 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture KaOYVWtJlWpMcw5oevEg with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 8AyF6deu157rVktQGfP5 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture RzH4W7OpvT1jMNLKHGOE with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture N1Spg1s0nztwnr1cXhpD with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture GzMbcBRy9txIw9h0lS4o with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture H5NjdS6dmpjG762IfN1K with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture OXTEN2Q3Ng78S71EUJZq with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture tLgCU08LGEzjD6qEO4qB with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture qnkp5jlV9aQJ0mAxK3S6 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture R0XdMK0cKdhs3ooEzQ1c with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture wmDQluSAi1ZwZHlTyvWN with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture NOhosAUs4XWxl6BipZS5 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture ky58g7rI7FzHIRVUPEgp with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture JYnEoH89B465XPTgDxNv with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 8ARgVIu4anTPBgo2gRIR with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture IOgimJsbJM7ljih4kRo8 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture prwcgaDEi55yEVtfBF4T with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture X7tMLN2PaBboTBwnbCAf with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture op75r1zi2FWsPRQv9lX2 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture u4m0Eq13HBUS5mW6BjQf with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture RBYqGxB9gNGWuCz82TRm with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture MHIlK7SIWICeAWWHxqzp with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture pz641QRzo5gBaB6k2vsj with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture HxXyWPrfEclZPvWAD1n4 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture j7mQZEq3RIzvtA83bXj9 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture MI9csWgp85slzRUTX3Pq with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture RzbL4Up6jSbkCjjclwv7 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture h403PZWelHKK3tLNFNEr with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 8zSCWqFA53o423TrAnbH with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture PGB6CM34iCxqX4uZTR1i with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture q0436Wd80bh3G39aB2ZR with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture izKLBh6bxIIQ6yyuLKR8 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 4qDtxEINYZRTpKsdkD4n with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture i4IHVlZ8FGEdnpWtdxid with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 1YvaI8k0ixkvvfVSoE2I with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture O5w9e6g8QwIyeue35YMt with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture DgSl2mNxKcUADTpb4Yte with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture AmVyjajzbCbO5v6nWwBY with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture i0lgN6Ec7xLt1qb44soV with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 7GMXqf4vqsKtjx6KY1x4 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture mW4q6SGjUa0RlXtfCNlY with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture tumNAFCuD9yTpnxYyF25 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture Lmqz0lc4V3c3u4E7O0SD with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture cd4kcsCx0o8Eav0NK0SA with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture TzcUOga8X9SJs8ioEeYj with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture y8ly1dZWpf0K5R5CnUsm with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture iwwb7fyBCBpmZ786obJ1 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture e9hG6r2IeUYHkUKelk97 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture I1N7ZU11JV5XEsolyHRh with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture PrMI9Kb1MXgcd85TO1TL with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture M114Cp2JqclxG3Y0LyKM with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture xCSeQOfQ0lXFWi28i2G1 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 3ydwTqhOScd3kx9pdw2L with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture yI2giilzE54m1CXxtqub with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture AIVfUS3zxVsYVSlp0FFw with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture cXG8rAu2SRo6qhjijyt1 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture FDxiCGaK90WN6yTFreXc with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture Q3u8kSwI0RtfTqrnxFtP with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture s3Abonjd4FEcJwZxrFLz with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 5per7lP7SyKtNSLcEZXN with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture pYoICoYPb0wXWzeqD2bW with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture kOxrXYq0yzK9mkzvLOjz with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture pz9hUlKDv5m3DivSA6zO with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 0k4ieMFsVHd1twnH0G92 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 2TUUXDxnMBkZyEzM1KdF with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture Nw9SWlFWw3b4JTxm1UIe with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture T5MtHS1t7SASunmIllUq with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture WfC7yXk6KxbOwCrQj53S with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture tPWBMR76ojvmDn5panM5 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture ovnQK0ZjACxtgaDYUp0I with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 44pfpxKdGJEEPnuximS6 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture ro8jlOnvp5sMrO2mFUl2 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture LOchYjVAUm2ITAI5AtV9 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture fZECx5QMhjUyJ9HGyVg3 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture uW4OiEaCiG91AWsRini5 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture BX4D03p2ycgDmvangsri with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture EqlZemLh0CTZ5qVKMuS1 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture n5RkdDxZ2NDAnBUoc7DB with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture a2wJ3uey0iKFX0jFqtj9 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture ScW1dEx5AzVANF6ERdsl with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture W5wN6ngyfLkDLq9Zy4hx with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture AjFOKfjCj1rlx0kf7kHq with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture mx3UrTmnR9x0OsFuqWz1 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture JRA30PDYNSgi92jp2H8Z with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture zLUFUI9h2xCfiQa410cd with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture JWaORV3leVgbJ08MZsU9 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture i2C448Dw9Qgwl2ARtuf4 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture hg5g6QOKteCpp3MiRNyK with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture UdUUF38mnM6hMBokmOGV with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture sd2cJYg6LDmyaYXLZdgD with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture qbgo8op8ITeTvSZ7F7Yv with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture WMNJjI5HokCbN4LG46zM with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture jafzSiXgZ9QWNcyhL5gM with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture sSCoXkzWlrP04GIMYzfC with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture NlaPqyxo3i4PTHtk49dm with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture Ea7uk0YkiZIXoMJgxCjp with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture JONIYfOftkyuUYG84KhN with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture iImDlzvy6HUuOd706UbW with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture CnXJ671WYsHIXoHkVGxP with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture wkku3kiTd2V3eoFLrHuW with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture nt2jS2jErz3ZjcRxwYd0 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 8v6rY9EXKWTFZfAPAVSI with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture VH7gUv8iFkYaqe7IyYWK with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture bZ5GpooKeoOwsSOxrTBl with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture VUHN16YmwZtwbgJyJHka with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 52yOaNx7iguchFDYVQcG with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture OxshnWSoD1AxR1gk922P with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture XyvpwoX0XYcVUK1imIZK with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture j0TAxn4TyKhsGxMQxq65 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture nZgmHR7ynVSxSOT3CZ75 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture Bs1HgLWciUZvUQCOha7D with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture fMZOdh6bYtaU53FmOVnf with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture oK94sLQ7f2B3kDlNnIX2 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture cz3PzdmhXJ0spWZ7d0Xj with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture rmyamlM1rQlww9JG3Jeu with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 9nJ167nWeKNs0DLOKuR7 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture P902yxx20gw90AXvu3Ey with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture JwYtgjmcTwRo2cN083am with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture jGdPqAC5Lo4TLXxPertx with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture jUqN592tMgboR2x3Y3BK with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 8qTEfgkmHeluJiVPM47W with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture vsa0bPugSufxr2LOyoCx with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 1vQrXfORN0mV4vhKKcbH with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture IbkoEFhV9r7ujJUQ09Z1 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture vmH1xlNYllH1Y8vcOmlG with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture nAcRA3o2pqXgsqRKC6HK with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 88qHQwiVzpPuM2nltT5S with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture Hm5CKToyMNXTmb4ed3nh with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 8hnI99lF2OkskL1fziq6 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 25ikWPr8W0NtiwUhmCe8 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture EdXejzeIOviVImeagk3s with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture dQCfut94oNbg3WPm9LSW with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture btvF41fpkT2BS2dUOqHn with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture kTA55UcfTFDicTN1grYd with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture qLZex7dvMspretEFaU4r with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture b0bYBmxidGPsKQCVFOhG with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture anTDu5P1BnCBgEY7gzS9 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture rJNR42fUXVWIgS3x4h7J with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture kC3ujoX3W0VcylBXfUQ3 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture u96vD6L8ggeo6V9Dzr88 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture I267qtu04JMxfw9gZlKK with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture UYH5WEnOc5kcXe6X6NmT with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 7wFOSi6GdnhEJZWS0HBS with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture wLzRisdgVa5Wu1mpshu0 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture LvRCfHwLQvzF3NICIYrQ with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture tFQJ9FAnuF4gCOwGMik5 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture LxTJwpmW2zwmPH5oun6z with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture 4v6kPca2JTJCichvhfZi with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']
# Opened Capture aLlZTQ7G2BhXJ0Tb0X00 with bands ['Blue', 'Green', 'Red', 'NIR', 'Red edge', 'Panchro']

# %% [markdown]
# ## Extended ImageSet examples
#
# A large group of images captured over a central California orchard are available for [download here](https://s3-us-west-2.amazonaws.com/sample.micasense.com/imageprocessing/RedEdgeImageSet.zip).
#
# With this set extracted to a working folder, the [extended ImageSet example](./ImageSets.ipynb) notebook provides more usages of ImageSet data.
#
# # Conclusion
#
# In this tutorial, we have introduced the MicaSense library and provided some examples of opening Images, Captures, and ImageSets, as well as detecting and extracting panel information from images.
#
# The next tutorial covers basic usage of DLS information, and is available [here](./MicaSense%20Image%20Processing%20Tutorial%203.ipynb)

# %% [markdown]
# ---
# Copyright (c) 2017-2019 MicaSense, Inc.  For licensing information see the [project git repository](https://github.com/micasense/imageprocessing)
